# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
# how to install python
python_url = 'https://www.youtube.com/watch?v=UvcQlPZ8ecA'

# %%
# how to install anaconda
conda_url = 'https://www.youtube.com/watch?v=YQWAiUhZJX8'

# %%
# how to create environments
conda_env_url = 'https://www.youtube.com/watch?v=1VVCd0eSkYc'

# %%
# https://www.geeksforgeeks.org/python-data-types/
# https://datacarpentry.org/python-socialsci/02-basics/index.html

# %%
img = cv2.imread('Figures/Python-data-structure.jpg')
plt.imshow(img)

# %% [markdown]
# ### Variable Assignment

# %%
# print(2+2)
a=2
b=2

# %%
a = 2
b = 3.142
c = a+b*a-b
c
# Out:
# 5.1419999999999995

# %% [markdown]
# ### Checking Data Types

# %%
print(type(a))
print(type(c))
s = "Hello world 2.0"
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### Arithmetic Operators

# %%
print("a =", a, "and b =" , b)
print(a + b)      # addition
print(a * b)      # multiplication
print(a - b)      # subtraction
print(a / b)      # division
print(b ** a)     # exponentiation
print(a % b)      # modulus - returns the remainder
print((2 * a) % b)  # modulus - returns the remainder
# Out:
# a = 2 and b = 3.142
# 5.1419999999999995
# 6.284
# -1.142
# 0.6365372374283896
# 9.872164
# 2.0
# 0.8580000000000001

# %% [markdown]
# ### Print and f strings

# %%
# print("a =", a, "and b =" , b)
print(f'a = {a} and b = {b:.2f}')
# Out:
# a = 2 and b = 3.14

# %% [markdown]
# ### Changing Data Types

# %%
a = 3.142
print(type(a))
a = 3
print(type(a))
a = a*1.0
print(type(a))
a = int(a)
print(type(a))
a = 3.142
a = int(a)
print(type(a))
print(a)
a = 3
# float(3)
str(a)
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# 3
# '3'

# %%
# errors

b = "Hello World"
print(type(b))

b = int(b)
print(type(b))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [69], line 6
#       3 b = "Hello World"
#       4 print(type(b))
# ----> 6 b = int(b)
#       7 print(type(b))
#
# ValueError: invalid literal for int() with base 10: 'Hello World'

# %% [markdown]
# ### String Basics

# %%
mystring = "Hello World"
print(mystring)

name = "Peter"
mystring = 'Hello ' + name + ' How are you?'
print(mystring)

name = "Peter"
mystring = 'Hello this is ' + name + "'s code"
print(mystring)
# Out:
# Hello World
# Hello Peter How are you?
# Hello this is Peter's code

# %%
myString = "The quick brown fox"

print(myString.startswith("The"))
print(myString.find("quick"))        # notice that string positions start with 0 like all indexing in Python
print(myString.upper())            # The contents of myString is not changed, if you wanted an uppercase version
print(myString)                    # you would have to assign it to a new variable
print(myString.split())            # splits at every (' ')
# Out:
# True
# 4
# THE QUICK BROWN FOX
# The quick brown fox
# ['The', 'quick', 'brown', 'fox']

# %%
myString[1]
# Out:
# 'h'

# %%
# strings are immutable

myString[0] = 'U'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [92], line 3
#       1 # strings are immutable
# ----> 3 myString[0] = 'U'
#
# TypeError: 'str' object does not support item assignment

# %%
a = 2
a = 3

name1 = 'Waleed'
name1
# Out:
# 'Waleed'

# %%
name2 = 'Hassan'
name2

name1 + name2
# Out:
# 'WaleedHassan'

# %%
# strings are ordered

print(myString[18])
print(myString[1:8])
# Out:
# x
# he quic

# %%
a = 3
a == 2
# Out:
# False

# %% [markdown]
# ### Bool Basics

# %%
print('hello' == 'HELLO')
print(3 != 77)
print(3 > 2)
# Out:
# False
# True
# True

# %% [markdown]
# ## Structured Data Types

# %% [markdown]
# ### Lists: Mutable and Ordered

# %%
list1 = [6, 54, 89]
print(list1)
print(type(list1))

list2 = [3.142, 2.71828, 9.8 ]
print(list2)
print(type(list2))

myname = "Peter"
list3 = ["Hello", 'to', myname]
print(list3)
myname = "Fred"
print(list3)
print(type(list3))

list4 = [6, 5.4, "numbers", True ]
print(list4)
print(type(list4))
# Out:
# [6, 54, 89]
# <class 'list'>
# [3.142, 2.71828, 9.8]
# <class 'list'>
# ['Hello', 'to', 'Peter']
# ['Hello', 'to', 'Peter']
# <class 'list'>
# [6, 5.4, 'numbers', True]
# <class 'list'>

# %%
list4[2] = 'num'
len(list4)
# list4.clear
# list4
# Out:
# 4

# %% [markdown]
# ### Tuples: Immutable and Ordered

# %%
tuple1 = (6, 5.4, "numbers", True)
print(tuple1)
print(type(tuple1))
# Out:
# (6, 5.4, 'numbers', True)
# <class 'tuple'>

# %% [markdown]
# ### Sets: Immutable and Unordered

# %%
# Creating a Set 
set1 = set() 
print("Initial empty Set: ") 
print(set1) 
    
# Creating a Set with  
# the use of a String 
set1 = set("GeeksForGeeks") 
print("\nSet with the use of String: ") 
print(set1) 
  
# Creating a Set with 
# the use of a List 
set1 = set(["Geeks", "For", "Geeks"]) 
print("\nSet with the use of List: ") 
print(set1) 
  
# Creating a Set with  
# a mixed type of values 
# (Having numbers and strings) 
set1 = set([1, 2, 'Geeks', 4, 'For', 6, 'Geeks']) 
print("\nSet with the use of Mixed Values") 
print(set1)

print(type(set1))
# Out:
# Initial empty Set:
# set()
#
# Set with the use of String:
# {'G', 'e', 'o', 'F', 'k', 'r', 's'}
#
# Set with the use of List:
# {'For', 'Geeks'}
#
# Set with the use of Mixed Values
# {1, 2, 'Geeks', 4, 6, 'For'}
# <class 'set'>

# %%
set1 = set("GeeksForGeeks") 

#intersection
#union
# Out:
# {'F', 'G', 'e', 'k', 'o', 'r', 's'}

# %% [markdown]
# ### Dictionaries: Mutable and Unordered

# %%
# Creating an empty Dictionary 
Dict = {} 
# dict()
print("Empty Dictionary: ") 
print(Dict) 
    
# Creating a Dictionary  
# with Integer Keys 
Dict = {1: 'Geeks', 2: 'For', 3: 'Geeks'} 
print("\nDictionary with the use of Integer Keys: ") 
print(Dict) 
    
# Creating a Dictionary  
# with Mixed keys 
Dict = {'Name': 'Geeks', 1: [1, 2, 3, 4]} 
print("\nDictionary with the use of Mixed Keys: ") 
print(Dict) 

print('\n', type(Dict))
# Out:
# Empty Dictionary:
# {}
#
# Dictionary with the use of Integer Keys:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}
#
# Dictionary with the use of Mixed Keys:
# {'Name': 'Geeks', 1: [1, 2, 3, 4]}
#
#  <class 'dict'>

# %%
Dict = {'Name': 'Bilal',
        'Age': 24,
        'FavSubs': ['maths', 'language']}

# print(Dict['FavSport'])
print(Dict.get('FavSport', 0) + 10)
# Out:
# 10

# %%
# # accessing a element using key 
# print("Accessing a element using key:") 
# print(Dict['asv']) 
  
# accessing a element using get() 
# method 
print("Accessing a element using get:") 
print(Dict.get('asv'))
# Out:
# Accessing a element using get:
# None

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'FavSubs'])
